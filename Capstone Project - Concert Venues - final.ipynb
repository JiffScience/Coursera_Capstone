# %% [markdown]
# # _Battle of the Neighborhoods - Concert Venues_

# %% [markdown]
# ## 1. Introduction / Business Problem

# %% [markdown]
# I am a musician, drum corps alumni/fanatic and therefore like to choose my travel and vacations based upon density and location of concert venues.  I am in the process of saving money for a big vacation for when cities and venues open post-COVID-19.  The following cities are on my bucket list:
#
# - New York, NY
# - San Francisco, CA
# - Seattle, WA
# - Boston, MA
# - Chicago, IL
#
# I will make my selection based on a combination of density and location of concert venues.  While I understand each of the above cities host a number of events on a regular basis, I am not sure of the density of said venues nor where I should make a hotel reservation.  The problem I want to solve is to analyze concert venue locations in the above cities and find a convenient area to make a hotel reservation.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# I will use the Foursquare application programming interface (API) to research and collect concert venue information for the aforementioned locations.  The data can be found here:
# - Foursquare Link: https://developer.foursquare.com/docs/build-with-foursquare/categories
# - Venue (concert hall) location code: 5032792091d4c4b30a586d5c
# Using the Foursquare data, I will construct a map of the above cities showing each concert hall location and conduct analysis to inform a decision regarding where to go on my vacation.
#
# A preview of the data is below.  However, before we can view the data, we need to install and import various libraries:

# %%
# Install geopy

# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.49)

# %%
# Install folium

# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)

# %%
# Import other libraries

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Establish Foursquare credentials

CLIENT_ID = 'E35M35R0TDYOGJIMFO3B5BPCFVHEZTOLIBB143AYE3MTOUVE' # your Foursquare ID
CLIENT_SECRET = 'BABTZXPQMIBOY12Y2UL15GFTOS4GWI5OCAX4VONCKFY4LKI3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
# Out:
# Your credentails:
# CLIENT_ID: E35M35R0TDYOGJIMFO3B5BPCFVHEZTOLIBB143AYE3MTOUVE

# %%
# Obrain the data from Foursquare

LIMIT = 500 # Maximum is 100
cities = ["New York, NY", 'Chicago, IL', 'San Francisco, CA', 'Seattle, WA', 'Boston, MA']
results = {}
for city in cities:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        city,
        LIMIT,
        "5032792091d4c4b30a586d5c") # Concert Hall place category ID
    results[city] = requests.get(url).json()

# %%
# View raw data to make sure the data is correctly imported

results
# Out:
# {'New York, NY': {'meta': {'code': 200,
#    'requestId': '5ee1373c1c213b7598830254'},
#   'response': {'suggestedFilters': {'header': 'Tap to show:',
#     'filters': [{'name': '$-$$$$', 'key': 'price'},
#      {'name': 'Open now', 'key': 'openNow'}]},
#    'geocode': {'what': '',
#     'where': 'new york ny',
#     'center': {'lat': 40.742185, 'lng': -73.992602},
#     'displayString': 'New York, NY, United States',
#     'cc': 'US',
#     'geometry': {'bounds': {'ne': {'lat': 40.882214, 'lng': -73.907},
#       'sw': {'lat': 40.679548, 'lng': -74.047285}}},
#     'slug': 'new-york-city-new-york',
#     'longId': '72057594043056517'},
#    'headerLocation': 'New York',
#    'headerFullLocation': 'New York',
#    'headerLocationGranularity': 'city',
#    'query': 'concert hall',
#    'totalResults': 80,
#    'suggestedBounds': {'ne': {'lat': 40.85926316355734,
#      'lng': -73.47752102706853},
#     'sw': {'lat': 40.58178665371454, 'lng': -74.03809494012417}},
#    'groups': [{'type': 'Recommended Places',
#      'name': 'recommended',
#      'items': [{'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '3fd66200f964a520b6e71ee3',
#         'name': 'Carnegie Hall',
#         'location': {'address': '881 7th Ave',
#          'crossStreet': 'at W 57th St',
#          'lat': 40.7651249,
#          'lng': -73.9799185,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.7651249,
#            'lng': -73.9799185},
#           {'label': 'entrance', 'lat': 40.765096, 'lng': -73.980151}],
#          'postalCode': '10019',
#          'cc': 'US',
#          'neighborhood': 'Theater District',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['881 7th Ave (at W 57th St)',
#           'New York, NY 10019',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-3fd66200f964a520b6e71ee3-0'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '43237380f964a520a6271fe3',
#         'name': 'David Geffen Hall',
#         'location': {'address': '10 Lincoln Center Plz',
#          'crossStreet': 'at W 65th St',
#          'lat': 40.772305363002324,
#          'lng': -73.983155909603,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.772305363002324,
#            'lng': -73.983155909603}],
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['10 Lincoln Center Plz (at W 65th St)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-43237380f964a520a6271fe3-1'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4161e400f964a520721d1fe3',
#         'name': 'Radio City Music Hall',
#         'location': {'address': '1260 Avenue of the Americas',
#          'crossStreet': 'at W 50th St',
#          'lat': 40.759850056828405,
#          'lng': -73.97934397752239,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.759850056828405,
#            'lng': -73.97934397752239}],
#          'postalCode': '10020',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1260 Avenue of the Americas (at W 50th St)',
#           'New York, NY 10020',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '34845694'}},
#        'referralId': 'e-0-4161e400f964a520721d1fe3-2'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5075fe7be4b0b3804ca1bd33',
#         'name': 'New York Philharmonic',
#         'location': {'address': '10 Lincoln Center Plz',
#          'crossStreet': 'at W 65th St',
#          'lat': 40.7725263585612,
#          'lng': -73.98313945354337,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.7725263585612,
#            'lng': -73.98313945354337}],
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['10 Lincoln Center Plz (at W 65th St)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '72984975'}},
#        'referralId': 'e-0-5075fe7be4b0b3804ca1bd33-3'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '3fd66200f964a52020e81ee3',
#         'name': 'Beacon Theatre',
#         'location': {'address': '2124 Broadway',
#          'crossStreet': 'at W 74th St',
#          'lat': 40.78055425266116,
#          'lng': -73.98043206426468,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.78055425266116,
#            'lng': -73.98043206426468}],
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['2124 Broadway (at W 74th St)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '34845687'}},
#        'referralId': 'e-0-3fd66200f964a52020e81ee3-4'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a315675f964a520b2991fe3',
#         'name': 'Alice Tully Hall',
#         'location': {'address': '1941 Broadway',
#          'crossStreet': 'at W 65th St',
#          'lat': 40.773358555297165,
#          'lng': -73.98237293981146,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.773358555297165,
#            'lng': -73.98237293981146}],
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1941 Broadway (at W 65th St)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4a315675f964a520b2991fe3-5'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '57881a4a498e97f50e26137a',
#         'name': 'Lion King Broadway Musical',
#         'location': {'lat': 40.75748093393903,
#          'lng': -73.98562260838094,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.75748093393903,
#            'lng': -73.98562260838094}],
#          'cc': 'US',
#          'neighborhood': 'Theater District',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['New York, NY', 'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-57881a4a498e97f50e26137a-6'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4ace86aff964a5200bd120e3',
#         'name': 'Zankel Hall at Carnegie Hall',
#         'location': {'address': '7th Ave and 57th St',
#          'crossStreet': '57th St',
#          'lat': 40.76500375725871,
#          'lng': -73.98043640043468,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.76500375725871,
#            'lng': -73.98043640043468}],
#          'postalCode': '10019',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['7th Ave and 57th St (57th St)',
#           'New York, NY 10019',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4ace86aff964a5200bd120e3-7'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4ae39d67f964a520489721e3',
#         'name': 'Weill Recital Hall at Carnegie Hall',
#         'location': {'address': '154 W 57th St',
#          'crossStreet': 'Seventh Ave',
#          'lat': 40.765366517574364,
#          'lng': -73.97952845936908,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.765366517574364,
#            'lng': -73.97952845936908}],
#          'postalCode': '10019',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['154 W 57th St (Seventh Ave)',
#           'New York, NY 10019',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4ae39d67f964a520489721e3-8'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5ab971da0e5da834db75692f',
#         'name': 'Sony Hall',
#         'location': {'address': '235 W 46th St',
#          'crossStreet': 'btw 7th & 8th Ave',
#          'lat': 40.759252964389084,
#          'lng': -73.98726994209605,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.759252964389084,
#            'lng': -73.98726994209605}],
#          'postalCode': '10036',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['235 W 46th St (btw 7th & 8th Ave)',
#           'New York, NY 10036',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5ab971da0e5da834db75692f-9'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '3fd66200f964a52023e81ee3',
#         'name': 'Lincoln Center for the Performing Arts',
#         'location': {'address': '70 Lincoln Center Plz',
#          'crossStreet': 'btwn Columbus & 10th Ave',
#          'lat': 40.772282300238174,
#          'lng': -73.98294841259204,
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['70 Lincoln Center Plz (btwn Columbus & 10th Ave)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1f2931735',
#           'name': 'Performing Arts Venue',
#           'pluralName': 'Performing Arts Venues',
#           'shortName': 'Performing Arts',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-3fd66200f964a52023e81ee3-10'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '54163328498eda4d0bb1640c',
#         'name': 'Pier 97',
#         'location': {'address': 'Henry Hudson Pkwy',
#          'crossStreet': 'at W 57th St',
#          'lat': 40.772096599703175,
#          'lng': -73.99556055767012,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.772096599703175,
#            'lng': -73.99556055767012}],
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['Henry Hudson Pkwy (at W 57th St)',
#           'New York, NY',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-54163328498eda4d0bb1640c-11'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '48e480eef964a52022521fe3',
#         'name': 'The Metropolitan Opera (Metropolitan Opera)',
#         'location': {'address': '70 Lincoln Center Plz',
#          'crossStreet': 'at Columbus Ave',
#          'lat': 40.77274188001071,
#          'lng': -73.9844012260437,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.77274188001071,
#            'lng': -73.9844012260437}],
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['70 Lincoln Center Plz (at Columbus Ave)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '35504286'}},
#        'referralId': 'e-0-48e480eef964a52022521fe3-12'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '49ff4eecf964a52005701fe3',
#         'name': 'David H. Koch Theater',
#         'location': {'address': 'Lincoln Center Plaza',
#          'crossStreet': 'at W 63rd St & Columbus Ave',
#          'lat': 40.772292228782284,
#          'lng': -73.9832624208871,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.772292228782284,
#            'lng': -73.9832624208871}],
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['Lincoln Center Plaza (at W 63rd St & Columbus Ave)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-49ff4eecf964a52005701fe3-13'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '49c54c1bf964a520ed561fe3',
#         'name': 'The Morgan Library & Museum',
#         'location': {'address': '225 Madison Ave',
#          'crossStreet': 'btwn E 36th & E 37th St',
#          'lat': 40.74930521896097,
#          'lng': -73.9814293384552,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.74930521896097,
#            'lng': -73.9814293384552},
#           {'label': 'entrance', 'lat': 40.749231, 'lng': -73.981594}],
#          'postalCode': '10016',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['225 Madison Ave (btwn E 36th & E 37th St)',
#           'New York, NY 10016',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-49c54c1bf964a520ed561fe3-14'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b7c0313f964a5206f782fe3',
#         'name': 'The National Opera Center',
#         'location': {'address': '330 7th Ave',
#          'crossStreet': 'W 29th St',
#          'lat': 40.74764376278695,
#          'lng': -73.9931058032815,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.74764376278695,
#            'lng': -73.9931058032815},
#           {'label': 'entrance', 'lat': 40.747682, 'lng': -73.993246}],
#          'postalCode': '10001',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['330 7th Ave (W 29th St)',
#           'New York, NY 10001',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '40553975'}},
#        'referralId': 'e-0-4b7c0313f964a5206f782fe3-15'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4cf95d8fc671721e9fc3b618',
#         'name': 'New York Live Arts',
#         'location': {'address': '219 W 19th St',
#          'crossStreet': 'btwn 7th & 8th Ave',
#          'lat': 40.74211775670745,
#          'lng': -73.9982682466507,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.74211775670745,
#            'lng': -73.9982682466507}],
#          'postalCode': '10011',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['219 W 19th St (btwn 7th & 8th Ave)',
#           'New York, NY 10011',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d137941735',
#           'name': 'Theater',
#           'pluralName': 'Theaters',
#           'shortName': 'Theater',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '34284016'}},
#        'referralId': 'e-0-4cf95d8fc671721e9fc3b618-16'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '51009f1391d4c6a2edc19697',
#         'name': 'SubCulture: Arts Underground',
#         'location': {'address': '45 Bleecker St, Downstairs',
#          'crossStreet': 'at Mulberry St',
#          'lat': 40.72579034329307,
#          'lng': -73.99448485710089,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.72579034329307,
#            'lng': -73.99448485710089}],
#          'postalCode': '10012',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['45 Bleecker St, Downstairs (at Mulberry St)',
#           'New York, NY 10012',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1e5931735',
#           'name': 'Music Venue',
#           'pluralName': 'Music Venues',
#           'shortName': 'Music Venue',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '48251643'}},
#        'referralId': 'e-0-51009f1391d4c6a2edc19697-17'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4f0f9d85e4b07e9ec8986efa',
#         'name': 'Voices of Gotham',
#         'location': {'address': '410 W 40th St',
#          'crossStreet': 'at 9th Ave.',
#          'lat': 40.757215262047424,
#          'lng': -73.99438169874057,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.757215262047424,
#            'lng': -73.99438169874057}],
#          'postalCode': '10036',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['410 W 40th St (at 9th Ave.)',
#           'New York, NY 10036',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '45841846'}},
#        'referralId': 'e-0-4f0f9d85e4b07e9ec8986efa-18'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a611294f964a520c4c11fe3',
#         'name': 'Irish Arts Center',
#         'location': {'address': '553 W 51st St',
#          'crossStreet': 'between 10th & 11th Ave',
#          'lat': 40.766326742011785,
#          'lng': -73.993898114934,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.766326742011785,
#            'lng': -73.993898114934},
#           {'label': 'entrance', 'lat': 40.76633, 'lng': -73.99353}],
#          'postalCode': '10019',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['553 W 51st St (between 10th & 11th Ave)',
#           'New York, NY 10019',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '61890012'}},
#        'referralId': 'e-0-4a611294f964a520c4c11fe3-19'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4345ba80f964a52079281fe3',
#         'name': 'Symphony Space',
#         'location': {'address': '2537 Broadway',
#          'crossStreet': 'at 95th St.',
#          'lat': 40.793846,
#          'lng': -73.972751,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.793846,
#            'lng': -73.972751}],
#          'postalCode': '10025',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['2537 Broadway (at 95th St.)',
#           'New York, NY 10025',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d137941735',
#           'name': 'Theater',
#           'pluralName': 'Theaters',
#           'shortName': 'Theater',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '39231376'}},
#        'referralId': 'e-0-4345ba80f964a52079281fe3-20'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '49cbdc03f964a52024591fe3',
#         'name': 'The Greene Space at WNYC',
#         'location': {'address': '44 Charlton St',
#          'crossStreet': 'Varick',
#          'lat': 40.727122463940745,
#          'lng': -74.00537489348002,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.727122463940745,
#            'lng': -74.00537489348002},
#           {'label': 'entrance', 'lat': 40.727028, 'lng': -74.005202}],
#          'postalCode': '10014',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['44 Charlton St (Varick)',
#           'New York, NY 10014',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-49cbdc03f964a52024591fe3-21'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b032755f964a5200f4d22e3',
#         'name': 'iHeartRadio Theater',
#         'location': {'address': '32 Avenue of the Americas',
#          'crossStreet': 'at Walker St',
#          'lat': 40.72031234030413,
#          'lng': -74.0051501071889,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.72031234030413,
#            'lng': -74.0051501071889}],
#          'postalCode': '10013',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['32 Avenue of the Americas (at Walker St)',
#           'New York, NY 10013',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '32694113'}},
#        'referralId': 'e-0-4b032755f964a5200f4d22e3-22'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '41f98080f964a5203a1f1fe3',
#         'name': 'The Town Hall',
#         'location': {'address': '123 W 43rd St',
#          'crossStreet': 'btwn Broadway & 6th Ave',
#          'lat': 40.756058317249185,
#          'lng': -73.98459477620275,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.756058317249185,
#            'lng': -73.98459477620275},
#           {'label': 'entrance', 'lat': 40.755995, 'lng': -73.984533}],
#          'postalCode': '10036',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['123 W 43rd St (btwn Broadway & 6th Ave)',
#           'New York, NY 10036',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '43761983'}},
#        'referralId': 'e-0-41f98080f964a5203a1f1fe3-23'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4eac93310aaf9e9a23c8e928',
#         'name': 'Kaufmann Concert Hall',
#         'location': {'address': '1395 Lexington Ave',
#          'crossStreet': 'in 92nd Street Y',
#          'lat': 40.78285245737033,
#          'lng': -73.95226299396008,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.78285245737033,
#            'lng': -73.95226299396008}],
#          'postalCode': '10128',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1395 Lexington Ave (in 92nd Street Y)',
#           'New York, NY 10128',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4eac93310aaf9e9a23c8e928-24'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '3fd66200f964a520aae31ee3',
#         'name': 'Hammerstein Ballroom',
#         'location': {'address': '311 W 34th St',
#          'crossStreet': 'btwn 8th & 9th Ave',
#          'lat': 40.75334284136246,
#          'lng': -73.99398226622483,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.75334284136246,
#            'lng': -73.99398226622483}],
#          'postalCode': '10001',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['311 W 34th St (btwn 8th & 9th Ave)',
#           'New York, NY 10001',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '38170749'}},
#        'referralId': 'e-0-3fd66200f964a520aae31ee3-25'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '475847d3f964a520cb4c1fe3',
#         'name': 'Gramercy Theatre',
#         'location': {'address': '127 E 23rd St',
#          'crossStreet': 'btwn Park & Lexington Ave',
#          'lat': 40.739745571666965,
#          'lng': -73.9851002638768,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.739745571666965,
#            'lng': -73.9851002638768}],
#          'postalCode': '10010',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['127 E 23rd St (btwn Park & Lexington Ave)',
#           'New York, NY 10010',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1e5931735',
#           'name': 'Music Venue',
#           'pluralName': 'Music Venues',
#           'shortName': 'Music Venue',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '39508034'}},
#        'referralId': 'e-0-475847d3f964a520cb4c1fe3-26'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '42fd3800f964a520ee261fe3',
#         'name': 'Alwan for the Arts',
#         'location': {'address': '16 Beaver St Ste 4',
#          'crossStreet': 'btw Broad St and Broadway',
#          'lat': 40.7049965901122,
#          'lng': -74.01261430771255,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.7049965901122,
#            'lng': -74.01261430771255}],
#          'postalCode': '10004',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['16 Beaver St Ste 4 (btw Broad St and Broadway)',
#           'New York, NY 10004',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '38235414'}},
#        'referralId': 'e-0-42fd3800f964a520ee261fe3-27'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '3fd66200f964a52024e81ee3',
#         'name': 'Merkin Concert Hall',
#         'location': {'address': '129 W 67th St',
#          'crossStreet': 'btw Broadway and Amsterdam',
#          'lat': 40.77517864857521,
#          'lng': -73.98312962481987,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.77517864857521,
#            'lng': -73.98312962481987}],
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['129 W 67th St (btw Broadway and Amsterdam)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '39097600'}},
#        'referralId': 'e-0-3fd66200f964a52024e81ee3-28'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '435c2400f964a52012291fe3',
#         'name': 'PlayStation Theater',
#         'location': {'address': '1515 Broadway',
#          'crossStreet': 'at W 44th St',
#          'lat': 40.75763318739876,
#          'lng': -73.98644330426343,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.75763318739876,
#            'lng': -73.98644330426343}],
#          'postalCode': '10036',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1515 Broadway (at W 44th St)',
#           'New York, NY 10036',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '94494088'}},
#        'referralId': 'e-0-435c2400f964a52012291fe3-29'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bdf5b66ffdec92864b8eba1',
#         'name': 'Peter Jay Sharp Theater',
#         'location': {'address': '155 W 65th St',
#          'crossStreet': 'btwn Amsterdam & Columbus Ave',
#          'lat': 40.77370184029355,
#          'lng': -73.98361156230322,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.77370184029355,
#            'lng': -73.98361156230322},
#           {'label': 'entrance', 'lat': 40.773695, 'lng': -73.983517}],
#          'postalCode': '10023',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['155 W 65th St (btwn Amsterdam & Columbus Ave)',
#           'New York, NY 10023',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '78864503'}},
#        'referralId': 'e-0-4bdf5b66ffdec92864b8eba1-30'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5188501e498e65952a9a6a9e',
#         'name': 'Ludlow Studios',
#         'location': {'address': '40 Ludlow St',
#          'crossStreet': 'Grand Street',
#          'lat': 40.716250940041455,
#          'lng': -73.99027818899935,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.716250940041455,
#            'lng': -73.99027818899935},
#           {'label': 'entrance', 'lat': 40.716182, 'lng': -73.990259}],
#          'postalCode': '10002',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['40 Ludlow St (Grand Street)',
#           'New York, NY 10002',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d173941735',
#           'name': 'Auditorium',
#           'pluralName': 'Auditoriums',
#           'shortName': 'Auditorium',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/auditorium_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '83742136'}},
#        'referralId': 'e-0-5188501e498e65952a9a6a9e-31'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a3ae715f964a52069a01fe3',
#         'name': 'Broad Street Ballroom',
#         'location': {'address': '41 Broad St',
#          'lat': 40.7057613381737,
#          'lng': -74.01128995536176,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.7057613381737,
#            'lng': -74.01128995536176}],
#          'postalCode': '10004',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['41 Broad St',
#           'New York, NY 10004',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4a3ae715f964a52069a01fe3-32'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4aa8e8b1f964a520c35120e3',
#         'name': 'Baruch Performing Arts Center',
#         'location': {'address': '55 Lexington Ave',
#          'crossStreet': 'at 25th Street',
#          'lat': 40.74024353882882,
#          'lng': -73.98382600959384,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.74024353882882,
#            'lng': -73.98382600959384}],
#          'postalCode': '10010',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['55 Lexington Ave (at 25th Street)',
#           'New York, NY 10010',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4aa8e8b1f964a520c35120e3-33'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '3fd66200f964a520f5ea1ee3',
#         'name': 'Apollo Theater',
#         'location': {'address': '253 W 125th St',
#          'crossStreet': 'btwn 7th & 8th Ave',
#          'lat': 40.80986187551455,
#          'lng': -73.95018783469122,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.80986187551455,
#            'lng': -73.95018783469122}],
#          'postalCode': '10027',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['253 W 125th St (btwn 7th & 8th Ave)',
#           'New York, NY 10027',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '81730546'}},
#        'referralId': 'e-0-3fd66200f964a520f5ea1ee3-34'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '50de3d05e4b0b7819ae447ec',
#         'name': 'Lyric Theatre',
#         'location': {'address': '213 W 42nd St',
#          'crossStreet': 'btwn 7th & 8th Ave',
#          'lat': 40.7565,
#          'lng': -73.98788,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.7565,
#            'lng': -73.98788},
#           {'label': 'entrance', 'lat': 40.757002, 'lng': -73.987375}],
#          'postalCode': '10036',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['213 W 42nd St (btwn 7th & 8th Ave)',
#           'New York, NY 10036',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d137941735',
#           'name': 'Theater',
#           'pluralName': 'Theaters',
#           'shortName': 'Theater',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-50de3d05e4b0b7819ae447ec-35'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b144da4f964a520d8a023e3',
#         'name': 'Bruno Walter Auditorium',
#         'location': {'address': '111 Amsterdam Ave',
#          'crossStreet': '65th Street',
#          'lat': 40.77397240564063,
#          'lng': -73.98499896736789,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.77397240564063,
# ...
#           'Boston, MA 02114',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '2046715',
#          'url': 'https://www.grubhub.com/restaurant/city-winery-boston-80-beverly-st-boston/2046715?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2046715',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-59a22c679be5223fd2737a93-12'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a884604f964a520aa0520e3',
#         'name': 'Citi Performing Arts Center Shubert Theatre',
#         'location': {'address': '265 Tremont St',
#          'crossStreet': 'btwn Oak & Stuart',
#          'lat': 42.350504228276364,
#          'lng': -71.0661228211988,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.350504228276364,
#            'lng': -71.0661228211988},
#           {'label': 'entrance', 'lat': 42.350318, 'lng': -71.065293}],
#          'postalCode': '02116',
#          'cc': 'US',
#          'neighborhood': 'Downtown Boston',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['265 Tremont St (btwn Oak & Stuart)',
#           'Boston, MA 02116',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d137941735',
#           'name': 'Theater',
#           'pluralName': 'Theaters',
#           'shortName': 'Theater',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '58509024'}},
#        'referralId': 'e-0-4a884604f964a520aa0520e3-13'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b563955f964a520210628e3',
#         'name': 'The Fenway Center',
#         'location': {'address': '77 St. Stephen St',
#          'lat': 42.34200271452115,
#          'lng': -71.08779458137735,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.34200271452115,
#            'lng': -71.08779458137735}],
#          'postalCode': '02115',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['77 St. Stephen St',
#           'Boston, MA 02115',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b563955f964a520210628e3-14'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bf472f5ff90c9b6ec465528',
#         'name': 'Cafe 939',
#         'location': {'address': '939 Boylston St',
#          'crossStreet': 'at Hereford St.',
#          'lat': 42.34812468961288,
#          'lng': -71.08489790462437,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.34812468961288,
#            'lng': -71.08489790462437}],
#          'postalCode': '02115',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['939 Boylston St (at Hereford St.)',
#           'Boston, MA 02115',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4bf472f5ff90c9b6ec465528-15'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4aea239af964a520b1b921e3',
#         'name': 'Tsai Performance Center',
#         'location': {'address': '685 Commonwealth Ave',
#          'lat': 42.350322858797554,
#          'lng': -71.10454614117644,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.350322858797554,
#            'lng': -71.10454614117644},
#           {'label': 'entrance', 'lat': 42.350222, 'lng': -71.105907}],
#          'postalCode': '02215',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['685 Commonwealth Ave',
#           'Boston, MA 02215',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d137941735',
#           'name': 'Theater',
#           'pluralName': 'Theaters',
#           'shortName': 'Theater',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4aea239af964a520b1b921e3-16'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a0fb7dcf964a52080761fe3',
#         'name': 'Orpheum Theatre',
#         'location': {'address': '1 Hamilton Pl',
#          'crossStreet': 'Tremont St',
#          'lat': 42.356710995256655,
#          'lng': -71.06042033287738,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.356710995256655,
#            'lng': -71.06042033287738}],
#          'postalCode': '02108',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['1 Hamilton Pl (Tremont St)',
#           'Boston, MA 02108',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '39508097'}},
#        'referralId': 'e-0-4a0fb7dcf964a52080761fe3-17'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4e493db615200c186697d398',
#         'name': 'Handel and Haydn Society Administrative Offices',
#         'location': {'address': '9 Harcourt St',
#          'lat': 42.34298609117609,
#          'lng': -71.08500235651734,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.34298609117609,
#            'lng': -71.08500235651734}],
#          'postalCode': '02116',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['9 Harcourt St',
#           'Boston, MA 02116',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4e493db615200c186697d398-18'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4d3f080d5f5488bf566847e6',
#         'name': 'New England Conservatory Williams Hall',
#         'location': {'address': 'Gainsborough St',
#          'crossStreet': 'Huntington Ave',
#          'lat': 42.34130048962385,
#          'lng': -71.08599245097123,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.34130048962385,
#            'lng': -71.08599245097123}],
#          'postalCode': '02115',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['Gainsborough St (Huntington Ave)',
#           'Boston, MA 02115',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4d3f080d5f5488bf566847e6-19'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5290fd4811d2df391d136cd5',
#         'name': 'Center Makor',
#         'location': {'address': '1845 Commonwealth Ave',
#          'lat': 42.339212484131565,
#          'lng': -71.15241765975952,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.339212484131565,
#            'lng': -71.15241765975952}],
#          'postalCode': '02135',
#          'cc': 'US',
#          'city': 'Brighton',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['1845 Commonwealth Ave',
#           'Brighton, MA 02135',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5290fd4811d2df391d136cd5-20'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4be5fc7fd4f7c9b60f402620',
#         'name': 'The Magic Room Gallery',
#         'location': {'address': '155 North Beacon St',
#          'lat': 42.35556325341557,
#          'lng': -71.14643284697028,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.35556325341557,
#            'lng': -71.14643284697028}],
#          'postalCode': '02135',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['155 North Beacon St',
#           'Boston, MA 02135',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4be5fc7fd4f7c9b60f402620-21'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4d124b444fc42c0fc20bc122',
#         'name': 'Hot 97 Boston [WPOT]',
#         'location': {'address': '1 Westinghouse Plz',
#          'crossStreet': 'Suite #1',
#          'lat': 42.24610137939453,
#          'lng': -71.13172149658203,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.24610137939453,
#            'lng': -71.13172149658203}],
#          'postalCode': '02136',
#          'cc': 'US',
#          'city': 'Hyde Park',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['1 Westinghouse Plz (Suite #1)',
#           'Hyde Park, MA 02136',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4d124b444fc42c0fc20bc122-22'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bf2db2dcad2c92839269a99',
#         'name': 'Tickets-for-Charity',
#         'location': {'address': '177 Huntington Ave Ste 2000',
#          'lat': 42.345451279295226,
#          'lng': -71.08311992053352,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.345451279295226,
#            'lng': -71.08311992053352}],
#          'postalCode': '02115',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['177 Huntington Ave Ste 2000',
#           'Boston, MA 02115',
#           'United States']},
#         'categories': [{'id': '5032792091d4c4b30a586d5c',
#           'name': 'Concert Hall',
#           'pluralName': 'Concert Halls',
#           'shortName': 'Concert Hall',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4bf2db2dcad2c92839269a99-23'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4ac80468f964a52039bb20e3',
#         'name': "Ned Devine's Irish Pub",
#         'location': {'address': '1 Commercial St',
#          'crossStreet': 'at Chatham St',
#          'lat': 42.36028429,
#          'lng': -71.05391965,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 42.36028429,
#            'lng': -71.05391965}],
#          'postalCode': '02109',
#          'cc': 'US',
#          'city': 'Boston',
#          'state': 'MA',
#          'country': 'United States',
#          'formattedAddress': ['1 Commercial St (at Chatham St)',
#           'Boston, MA 02109',
#           'United States']},
#         'categories': [{'id': '52e81612bcbc57f1066b7a06',
#           'name': 'Irish Pub',
#           'pluralName': 'Irish Pubs',
#           'shortName': 'Irish',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '33417723'}},
#        'referralId': 'e-0-4ac80468f964a52039bb20e3-24'}]}]}}}

# %%
# Create a master dataframe to consolidate data for easy viewing and analysis.

df_master = pd.DataFrame(columns = ['City', 'Num Venues', 'MDMC'])

# City = the name of the respective city
# Num Venues = the number of concert venues in the respective city
# MDMC = mean distance from mean coordinates for the respective city cluster

df_master['City'] = cities
df_master
# Out:
#                 City Num Venues MDMC
# 0       New York, NY        NaN  NaN
# 1        Chicago, IL        NaN  NaN
# 2  San Francisco, CA        NaN  NaN
# 3        Seattle, WA        NaN  NaN
# 4         Boston, MA        NaN  NaN

# %% [markdown]
# ## 3. Methodology
#
# The methodology used is to examine the aforementioned Foursquare data for "Concert Halls" to do three things: (1) calculate the total number of concert venues in each city, (2) calculate the centroid (or mean coordinate) of said venues in each city, and (3) use this information to make a more informed decision regarding where to take a nice vacation post COVID-19.  The data will be examined to minimize influence of outlier data points (e.g., distant concert halls).

# %%
# Create a dataframe of the concert venues for each city.

df_venues={}
for city in cities:
    venues = json_normalize(results[city]['response']['groups'][0]['items'])
    df_venues[city] = venues[['venue.name', 'venue.location.address', 'venue.location.lat', 'venue.location.lng']]
    df_venues[city].columns = ['Name', 'Address', 'Lat', 'Lng']

# %%
# Calculate the number of concert venues in each city.

list_numvenues = []
maps = {}
for city in cities:
    city_lat = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps[city] = folium.Map(location=[city_lat, city_lng], zoom_start=11)

    # add markers to map
    for lat, lng, label in zip(df_venues[city]['Lat'], df_venues[city]['Lng'], df_venues[city]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(maps[city])  

    print(f"Total number of concert halls in {city} = ", results[city]['response']['totalResults'])
    print("Showing Top 100")
    list_numvenues.append(results[city]['response']['totalResults'])
list_numvenues
# Out:
# Total number of concert halls in New York, NY =  80
# Showing Top 100
# Total number of concert halls in Chicago, IL =  45
# Showing Top 100
# Total number of concert halls in San Francisco, CA =  26
# Showing Top 100
# Total number of concert halls in Seattle, WA =  17
# Showing Top 100
# Total number of concert halls in Boston, MA =  25
# Showing Top 100
# [80, 45, 26, 17, 25]

# %%
# The following maps depict the location of concert halls in each city.
maps[cities[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[2]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[3]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[4]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Calcuate the mean distance of each concert hall from the mean centroid/coordinate of said cluster.  
# Please note below the line item that removes from the data set the three (3) most distant venues.

list_MDMC = []

maps = {}

for city in cities:
    city_lat = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps[city] = folium.Map(location=[city_lat, city_lng], zoom_start=11)
    venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 
    # add markers to map
    for lat, lng, label in zip(df_venues[city]['Lat'], df_venues[city]['Lng'], df_venues[city]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(maps[city])
        folium.PolyLine([venues_mean_coor, [lat, lng]], color="green", weight=1.5, opacity=0.5).add_to(maps[city])
    
    label = folium.Popup("Mean Co-ordinate", parse_html=True)
    folium.CircleMarker(
        venues_mean_coor,
        radius=10,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(maps[city])

    venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 
    print(city)
    print("Mean Distance from Mean coordinates")
    dists = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coor),1,df_venues[city][['Lat','Lng']].values)
    dists.sort()
    value = np.mean(dists[:-3]) # Ignore the three most distant concert halls for each city in the MDMC calculation
    print(value)
    list_MDMC.append(value)
list_MDMC
# Out:
# New York, NY
# Mean Distance from Mean coordinates
# 0.037085463733032335
# Chicago, IL
# Mean Distance from Mean coordinates
# 0.04859572181663778
# San Francisco, CA
# Mean Distance from Mean coordinates
# 0.011450706000091671
# Seattle, WA
# Mean Distance from Mean coordinates
# 0.0345251108598156
# Boston, MA
# Mean Distance from Mean coordinates
# 0.013596709090995179
# [0.037085463733032335,
#  0.04859572181663778,
#  0.011450706000091671,
#  0.0345251108598156,
#  0.013596709090995179]

# %%
maps[cities[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[2]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[3]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[3]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4. Results
#
# This section contains consolidated results from the above analysis.  The table below lists for each city, the total number of concert halls, and the mean distance to the mean centroid/coordinate the respective cluster of said venues.  Examining the data, most of the cities have ~3 outlier data points.  Therefore, the three most distant venues were removed from each data set as to not skew results.

# %%
# The following is a consolidated dataframe listing each city, and for each one, the number of concert halls and mean distance from the mean coordinate/centroid of said cluster.

df_master['Num Venues'] = list_numvenues
df_master['MDMC'] = list_MDMC
df_master.sort_values(by = ['MDMC'])
# Out:
#                 City  Num Venues      MDMC
# 2  San Francisco, CA          26  0.011451
# 4         Boston, MA          25  0.013597
# 3        Seattle, WA          17  0.034525
# 0       New York, NY          80  0.037085
# 1        Chicago, IL          45  0.048596

# %% [markdown]
# ## 5. Discussion
#
# New York, NY clearly possesses the greatest quantity of concert halls relative to the other cities; nearly twice as much for each, but the mean distance to the mean centroid/coordinate (MDMC) is higher than other cities (0.037 km).  San Francisco, CA and Boston, MA each have ~25 venues with a similar MDMC of ~0.01 km.  All cities have several venues within a convenient distance from their respective concert hall MDMC.

# %% [markdown]
# ## 6. Conclusion
#
# New York, NY appears to be the best choice for me to visit for my next vacation.  It offers nearly twice the number of concert halls relative to the other cities examined in this project.  While New York's MDMC is higher than three other cities (San Francisco, Boston and Seattle), it is only ~0.024 km more, which is negligible.  Therefore, I will keep my eye on when concert venues in New York, NY start to open post COVID-19 and when they do, make a reservation in a hotel vicinity the center of New York's concert venues.
